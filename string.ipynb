# %%
# WriteaprogramtoinputTstrings(S)fromuserandprintcountofvowelsandconsonantsinit.
 #Input:
 #2
 #List
 #Apple
T=int(input())
for i in range(T):
    s=input()
    v=0
    c=0
    for j in s:
        if j in 'aeiouAEIOU':
            v+=1
        elif j.isalpha():
            c+=1
    print(v,c)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       1 # WriteaprogramtoinputTstrings(S)fromuserandprintcountofvowelsandconsonantsinit.
#       2  #Input:
#       3  #2
#       4  #List
#       5  #Apple
# ----> 6 T=int(input())
#       7 for i in range(T):
#       8     s=input()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# ...

# %%
# question 2 length of string
n="python"
s=len(n)
print(s)
# Out:
# 6

# %%
# question 3 pailindrome
n="malayalam"
s=n[::-1]
if n==s:
    print(" string is pailindrome")
else:
    print("not a pailindrome")
# Out:
#  string is pailindrome

# %%
# question 4 [ input  A="**h*e*l*lo*" , output = h*e*l*lo]

h="**h*e*l*lo*"
v=h.strip("*")
print(v)
# Out:
# h*e*l*lo

# %%
# question 5 
h= "**he!ll0*"
v = h.lstrip("*")
print(v)
# Out:
# he!ll0*

# %%
#question 6 
h = "hello^%$#E&*"

v= h.rstrip("^%$#E&*")
print(v)
# Out:
# hello

# %%
# question 7 reverse a string
N = "python"
s=N[::-1]
print(s)
# Out:
# nohtyp

# %%
# 17  Concatenate the string with itself.
'''Delete all the uppercase letters.
 Replace each vowel with '#'.
 You are given a string A of size N consisting of lowercase and uppercase alphabets. Return the
 resultant string after applying the above operations.
 NOTE: 'a' , 'e' , 'i' , 'o' , 'u' are defined as vowels'''


a="aeiOUzy"
a=a+a
b=""
for i in a:
    if i.islower():
        if i in 'aeiou':
            b+='#'
        else:
            b+=i
print(b)
# Out:
# ###zy###zy
